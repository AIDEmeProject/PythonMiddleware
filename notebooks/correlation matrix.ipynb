# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
#%matplotlib inline

data = pd.read_csv('/Users/luciano/Downloads/final_19101100.csv', sep=';')
data.head()
# Out:
#           id  year  length_m  width_m  height_m  base_engine_size_l  \
# 0  200713717  2016   4.62026  1.79324   1.41224                 2.4
# 1  200727572  2016   4.62026  1.79324   1.41224                 2.4
# 2  200727571  2016   4.62026  1.79324   1.41224                 2.4
# 3  200727568  2016   4.62026  1.79324   1.41224                 2.4
# 4  200727569  2016   4.62026  1.79324   1.41224                 2.4
#
#    horsepower_hp  horsepower_rpm  torque_ft_kg  torque_rpm  \
# 0          201.0          6800.0            81      3800.0
# 1          201.0          6800.0            81      3800.0
# 2          201.0          6800.0            81      3800.0
# 3          201.0          6800.0            81      3800.0
# 4          201.0          6800.0            81      3800.0
#
#             ...            color_centroid_0_0_127  color_centroid_127_127_0  \
# 0           ...                             False                      True
# 1           ...                             False                      True
# 2           ...                             False                      True
# 3           ...                             False                     False
# 4           ...                             False                      True
#
#    color_centroid_0_127_127  color_centroid_127_0_0  \
# 0                     False                    True
# 1                     False                    True
# 2                     False                    True
# 3                     False                    True
# 4                     False                    True
#
#    color_centroid_255_128_128  color_centroid_255_0_128  \
# 0                       False                     False
# 1                       False                     False
# 2                       False                     False
# 3                       False                     False
# 4                       False                     False
#
#    color_centroid_127_0_128  color_centroid_255_0_0  color_centroid_64_0_0  \
# 0                     False                    True                   True
# 1                     False                    True                   True
# 2                     False                    True                   True
# 3                     False                    True                   True
# 4                     False                    True                   True
#
#    color_centroid_191_0_0
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
#
# [5 rows x 551 columns]

# %%
# get correlation matrix
corr = data.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(100, 100))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5)#, cbar_kws={"shrink": .5})

f.savefig('/Users/luciano/Downloads/correlation_plot.png')

# %%
sns.heatmap?

# %%
np.reshape([1,2,3,4, 5, 6], (2, -1))
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])
